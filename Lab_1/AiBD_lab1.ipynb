# %% [markdown]
# # **Adrian Poniatowski, grupa 2b**

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## **Zadanie 3**
#
# W tym zadaniu należało zdefiniować funkcję oraz sporządzić jej wykres dla argumentów z konkretnych przedziałów. Do wizualizacji wyników skorzystałem z pakietu Matplotlib.

# %%
def func(x):
  return x**2 + 5

# %% [markdown]
# Pierwszy przedział: $x>-1$ oraz $x<1$

# %%
first = np.linspace(-1, 1)
plt.plot(first, func(first), label="$f(x)=x^2+5$")
plt.xlabel("Argumenty")
plt.ylabel("Wartości")
plt.title("Wykres funkcji dla pierwszego przedziału")
plt.legend()
plt.show()

# %% [markdown]
# Drugi przedział: $x>-6$ oraz $x<6$

# %%
second = np.linspace(-6, 6)
plt.plot(second, func(second), label="$f(x)=x^2+5$")
plt.xlabel("Argumenty")
plt.ylabel("Wartości")
plt.title("Wykres funkcji dla drugiego przedziału")
plt.legend()
plt.show()

# %% [markdown]
# Trzeci przedział: $x>0$ oraz $x<5$

# %%
third = np.linspace(0, 5)
plt.plot(third, func(third), label="$f(x)=x^2+5$")
plt.xlabel("Argumenty")
plt.ylabel("Wartości")
plt.title("Wykres funkcji dla trzeciego przedziału")
plt.legend()
plt.show()

# %% [markdown]
# Wszystkie wykresy przedstawiają poprawny przebieg funkcji. Do stworzenia odpowiednich przedziałów skorzystałem z funkcji *linspace* dostępnej w pakiecie Numpy.

# %% [markdown]
# ## **Zadanie 4**
#
# W tym zadaniu należało utworzyć DataFrame z odpowiednimi nazwami kolumn. Następnie dowolnie je uzupełnić oraz wyświetlić informacje o danych, opis danych oraz trzy pierwsze rekordy. Do wykonania tego zadania skorzystałem z pakietu Pandas.

# %%
data = [["Jan", "Kowalski", 42, "Male"],
        ["Aneta", "Nowak", 19, "Female"],
        ["Marcin", "Bracki", 15, "Male"],
        ["Andrzej", "Siatkowski", 65, "Male"],
        ["Monika", "Studzińska", 39, "Female"]]
dataframe = pd.DataFrame(data)
dataframe.columns = "Name", "Surname", "Age", "Sex"

# %% [markdown]
# Wyświetlenie całego dataframe:

# %%
dataframe
# Out:
#       Name     Surname  Age     Sex
# 0      Jan    Kowalski   42    Male
# 1    Aneta       Nowak   19  Female
# 2   Marcin      Bracki   15    Male
# 3  Andrzej  Siatkowski   65    Male
# 4   Monika  Studzińska   39  Female

# %% [markdown]
# Wyświetlenie informacji o danych za pomocą funkcji *info*:

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     5 non-null      object
#  1   Surname  5 non-null      object
#  2   Age      5 non-null      int64
#  3   Sex      5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 288.0+ bytes

# %% [markdown]
# Wyświetlenie opisu danych za pomocą funkcji *describe*:

# %%
dataframe.describe(include='all')
# Out:
#        Name   Surname        Age   Sex
# count     5         5   5.000000     5
# unique    5         5        NaN     2
# top     Jan  Kowalski        NaN  Male
# freq      1         1        NaN     3
# mean    NaN       NaN  36.000000   NaN
# std     NaN       NaN  20.099751   NaN
# min     NaN       NaN  15.000000   NaN
# 25%     NaN       NaN  19.000000   NaN
# 50%     NaN       NaN  39.000000   NaN
# 75%     NaN       NaN  42.000000   NaN
# max     NaN       NaN  65.000000   NaN

# %% [markdown]
# Wyświetlenie pierwszych trzech rekordów za pomocą funkcji *head*

# %%
dataframe.head(3)
# Out:
#      Name   Surname  Age     Sex
# 0     Jan  Kowalski   42    Male
# 1   Aneta     Nowak   19  Female
# 2  Marcin    Bracki   15    Male

# %% [markdown]
# Działania każdej z funkcji były zgodne z oczekiwaniami. Dla mnie jest to dopiero początek obcowania z pakietem Pandas, dlatego niezbędna okazała się jego dokumentacja.
